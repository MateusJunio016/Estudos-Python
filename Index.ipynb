# %% [markdown]
# # Funções

# %%
# Funções Gerais

opcao = 0
def mostrar_menu():
  print("\n\nCadastro de alunos")
  print("1 - Cadastrar")
  print("2 - Listar")
  print("3 - Sair")

def receber_opcao():
  opcao = int(input("\nEscolha a sua opção: "))
  if opcao not in [1, 2, 3]:
      print("Opção inválida!")
  elif opcao == 1:
    cadastrar_aluno()
  elif opcao == 2:
    listar_alunos()

  return opcao


def cadastrar_aluno():
  nome = input("\nInforme o nome do aluno: ")
  #dados_alunos.append(nome)
  with open('/content/dados.txt', 'a+') as arquivo:
    arquivo.write(nome + "\n")

def listar_alunos():
  with open('/content/dados.txt', 'r') as arquivo:
    registros = arquivo.readlines()

    for aluno in registros:
      print(f"\nAluno cadastrado {aluno}")

# %% [markdown]
# ## Execução:

# %%
while opcao != 3:
  mostrar_menu()
  opcao = receber_opcao()
# Out:
# Cadastro de alunos
# 1 - Cadastrar
# 2 - Listar
# 3 - Sair
#
# Escolha a sua opção: 1
#
# Informe o nome do aluno: Agnaldo
#
#
# Cadastro de alunos
# 1 - Cadastrar
# 2 - Listar
# 3 - Sair
#
# Escolha a sua opção: 1
#
# Informe o nome do aluno: Pietra
#
#
# Cadastro de alunos
# 1 - Cadastrar
# 2 - Listar
# 3 - Sair
#
# Escolha a sua opção: 2
#
# Aluno cadastrado jr
#
#
# Aluno cadastrado Agnaldo
#
#
# Aluno cadastrado Pietra
#
#
#
# Cadastro de alunos
# 1 - Cadastrar
# 2 - Listar
# 3 - Sair
#
# Escolha a sua opção: 3
